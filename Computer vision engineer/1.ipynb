# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("parrot.jpeg")

# %%
# %matplotlib inline
def plotimage(img):
    print("Dimension of image", img.shape)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
plotimage(img)
# Out:
# Dimension of image (225, 225, 3)
